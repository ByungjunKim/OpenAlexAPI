# %%
import pandas as pd
import json
import glob
from tqdm import tqdm
tqdm.pandas()

# %%
# json 파일 리스트
file_list = glob.glob('./renewable_json/*.json')
len(file_list)
# Out:
# 1000

# %%
# 여러 json 파일을 읽어서 result만 하나의 리스트로 저장하기
openalex_json = []
for file in tqdm(file_list):
    with open(file,'r') as f:
        temp_json = json.load(f)['results']
    openalex_json.extend(temp_json)
# Out:
# 100%|██████████| 1000/1000 [00:40<00:00, 24.43it/s]

# %%
# pandas dataframe으로 변환
df = pd.DataFrame.from_dict(openalex_json)
df
# Out:
#                                       id
# 0       https://openalex.org/W2046389536  \
# 1       https://openalex.org/W2757065440
# 2       https://openalex.org/W1969235198
# 3       https://openalex.org/W4229064923
# 4       https://openalex.org/W1570677810
# ...                                  ...
# 199995  https://openalex.org/W4283748928
# 199996  https://openalex.org/W2057696289
# 199997  https://openalex.org/W1980630824
# 199998  https://openalex.org/W3048378484
# 199999  https://openalex.org/W2751734142
#
#                                                     doi
# 0       https://doi.org/10.1109/isgteurope.2014.7028916  \
# 1                     https://doi.org/10.1115/1.4038048
# 2             https://doi.org/10.1109/ecce.2012.6342824
# 3             https://doi.org/10.1016/j.est.2022.104629
# 4                       https://doi.org/10.2172/1048985
# ...                                                 ...
# 199995               https://doi.org/10.3390/en15134800
# 199996       https://doi.org/10.1109/mspec.2013.6511107
# 199997  https://doi.org/10.1109/isgteurope.2012.6465753
# 199998            https://doi.org/10.3390/polym12081795
# 199999    https://doi.org/10.1016/j.ecolind.2017.08.054
#
#                                                     title
# 0              A review of demand response business cases  \
# 1       Sizing of a Photovoltaic-Wind-Oil Shale Hybrid...
# 2       Black start control of a solid state transform...
# 3       Application of load frequency control method t...
# 4       Zero Emission Bay Area (ZEBA) Fuel Cell Bus De...
# ...                                                   ...
# 199995  Simulation of Two-Phase Flow and Syngas Genera...
# 199996                  Germany jump-starts the supergrid
# 199997  Communication interface requirements during cr...
# 199998  Insights into the Potential of Hardwood Kraft ...
# 199999             Exergy analysis of Chinese agriculture
#
#                                              display_name  relevance_score
# 0              A review of demand response business cases       114.100780  \
# 1       Sizing of a Photovoltaic-Wind-Oil Shale Hybrid...       114.092880
# 2       Black start control of a solid state transform...       114.091770
# 3       Application of load frequency control method t...       114.088646
# 4       Zero Emission Bay Area (ZEBA) Fuel Cell Bus De...       114.087600
# ...                                                   ...              ...
# 199995  Simulation of Two-Phase Flow and Syngas Genera...        50.820840
# 199996                  Germany jump-starts the supergrid        50.819770
# 199997  Communication interface requirements during cr...        50.818558
# 199998  Insights into the Potential of Hardwood Kraft ...        50.818478
# 199999             Exergy analysis of Chinese agriculture        50.817660
#
#         publication_year publication_date
# 0                   2014       2014-10-01  \
# 1                   2018       2018-02-01
# 2                   2012       2012-11-12
# 3                   2022       2022-08-01
# 4                   2012       2012-07-01
# ...                  ...              ...
# 199995              2022       2022-06-30
# 199996              2013       2013-05-02
# 199997              2012       2012-10-01
# 199998              2020       2020-08-11
# 199999              2017       2017-08-31
#
#                                                       ids
# 0       {'openalex': 'https://openalex.org/W2046389536...  \
# 1       {'openalex': 'https://openalex.org/W2757065440...
# 2       {'openalex': 'https://openalex.org/W1969235198...
# 3       {'openalex': 'https://openalex.org/W4229064923...
# 4       {'openalex': 'https://openalex.org/W1570677810...
# ...                                                   ...
# 199995  {'openalex': 'https://openalex.org/W4283748928...
# 199996  {'openalex': 'https://openalex.org/W2057696289...
# 199997  {'openalex': 'https://openalex.org/W1980630824...
# 199998  {'openalex': 'https://openalex.org/W3048378484...
# 199999  {'openalex': 'https://openalex.org/W2751734142...
#
#                                          primary_location
# 0       {'is_oa': False, 'landing_page_url': 'https://...  \
# 1       {'is_oa': False, 'landing_page_url': 'https://...
# 2       {'is_oa': False, 'landing_page_url': 'https://...
# 3       {'is_oa': False, 'landing_page_url': 'https://...
# 4       {'is_oa': False, 'landing_page_url': 'https://...
# ...                                                   ...
# 199995  {'is_oa': True, 'landing_page_url': 'https://d...
# 199996  {'is_oa': False, 'landing_page_url': 'https://...
# 199997  {'is_oa': False, 'landing_page_url': 'https://...
# 199998  {'is_oa': True, 'landing_page_url': 'https://d...
# 199999  {'is_oa': False, 'landing_page_url': 'https://...
#
#                        type  ...
# 0       proceedings-article  ...  \
# 1           journal-article  ...
# 2       proceedings-article  ...
# 3           journal-article  ...
# 4                    report  ...
# ...                     ...  ...
# 199995      journal-article  ...
# 199996      journal-article  ...
# 199997  proceedings-article  ...
# 199998      journal-article  ...
# 199999      journal-article  ...
#
#                                                    grants
# 0                                                      []  \
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 199995  [{'funder': 'https://openalex.org/F4320311970'...
# 199996                                                 []
# 199997                                                 []
# 199998                                                 []
# 199999                                                 []
#
#                                          referenced_works
# 0       [https://openalex.org/W1787290749, https://ope...  \
# 1       [https://openalex.org/W1779223984, https://ope...
# 2       [https://openalex.org/W2136700375, https://ope...
# 3       [https://openalex.org/W1975774546, https://ope...
# 4       [https://openalex.org/W260040727, https://open...
# ...                                                   ...
# 199995  [https://openalex.org/W1965166118, https://ope...
# 199996                                                 []
# 199997  [https://openalex.org/W160743974, https://open...
# 199998  [https://openalex.org/W1160305686, https://ope...
# 199999  [https://openalex.org/W293584014, https://open...
#
#                                             related_works
# 0       [https://openalex.org/W1497055392, https://ope...  \
# 1       [https://openalex.org/W1965384568, https://ope...
# 2       [https://openalex.org/W1992568949, https://ope...
# 3       [https://openalex.org/W2059288099, https://ope...
# 4       [https://openalex.org/W289857799, https://open...
# ...                                                   ...
# 199995  [https://openalex.org/W58903434, https://opena...
# 199996  [https://openalex.org/W2080674165, https://ope...
# 199997  [https://openalex.org/W1480216841, https://ope...
# 199998  [https://openalex.org/W2045342989, https://ope...
# 199999  [https://openalex.org/W1572889832, https://ope...
#
#                                                ngrams_url
# 0       https://api.openalex.org/works/W2046389536/ngrams  \
# 1       https://api.openalex.org/works/W2757065440/ngrams
# 2       https://api.openalex.org/works/W1969235198/ngrams
# 3       https://api.openalex.org/works/W4229064923/ngrams
# 4       https://api.openalex.org/works/W1570677810/ngrams
# ...                                                   ...
# 199995  https://api.openalex.org/works/W4283748928/ngrams
# 199996  https://api.openalex.org/works/W2057696289/ngrams
# 199997  https://api.openalex.org/works/W1980630824/ngrams
# 199998  https://api.openalex.org/works/W3048378484/ngrams
# 199999  https://api.openalex.org/works/W2751734142/ngrams
#
#                                   abstract_inverted_index
# 0       {'Demand': [0], 'Response': [1], '(DR)': [2], ...  \
# 1       {'The': [0, 115, 175], 'integration': [1, 32, ...
# 2       {'This': [0], 'paper': [1, 60], 'demonstrates'...
# 3       {'Active': [0], 'power': [1], 'and': [2, 35, 5...
# 4       {'This': [0, 42], 'report': [1, 87, 109], 'pre...
# ...                                                   ...
# 199995  {'The': [0, 114], 'efficient': [1], 'use': [2]...
# 199996  {'New': [0], 'developments': [1], 'in': [2, 11...
# 199997  {'The': [0], 'power': [1, 35], 'system': [2, 3...
# 199998  {'Lignin': [0], 'is': [1, 143, 169], 'an': [2]...
# 199999  {'•': [0, 13, 24, 34, 46], 'An': [1], 'in-dept...
#
#                                          cited_by_api_url
# 0       https://api.openalex.org/works?filter=cites:W2...  \
# 1       https://api.openalex.org/works?filter=cites:W2...
# 2       https://api.openalex.org/works?filter=cites:W1...
# 3       https://api.openalex.org/works?filter=cites:W4...
# 4       https://api.openalex.org/works?filter=cites:W1...
# ...                                                   ...
# 199995  https://api.openalex.org/works?filter=cites:W4...
# 199996  https://api.openalex.org/works?filter=cites:W2...
# 199997  https://api.openalex.org/works?filter=cites:W1...
# 199998  https://api.openalex.org/works?filter=cites:W3...
# 199999  https://api.openalex.org/works?filter=cites:W2...
#
#                                            counts_by_year
# 0       [{'year': 2022, 'cited_by_count': 1}, {'year':...  \
# 1       [{'year': 2023, 'cited_by_count': 1}, {'year':...
# 2       [{'year': 2023, 'cited_by_count': 1}, {'year':...
# 3       [{'year': 2023, 'cited_by_count': 6}, {'year':...
# 4       [{'year': 2017, 'cited_by_count': 2}, {'year':...
# ...                                                   ...
# 199995              [{'year': 2022, 'cited_by_count': 2}]
# 199996  [{'year': 2022, 'cited_by_count': 4}, {'year':...
# 199997  [{'year': 2019, 'cited_by_count': 1}, {'year':...
# 199998  [{'year': 2023, 'cited_by_count': 10}, {'year'...
# 199999  [{'year': 2023, 'cited_by_count': 3}, {'year':...
#
#                       updated_date  created_date is_authors_truncated
# 0       2023-04-28T01:22:00.357992    2016-06-24                  NaN
# 1       2023-04-30T20:01:45.378594    2017-10-06                  NaN
# 2       2023-04-27T17:49:20.876350    2016-06-24                  NaN
# 3       2023-04-28T15:21:50.399968    2022-05-08                  NaN
# 4       2023-05-04T07:36:42.511435    2016-06-24                  NaN
# ...                            ...           ...                  ...
# 199995  2023-05-03T06:13:00.570166    2022-07-02                  NaN
# 199996  2023-04-29T13:01:19.950514    2016-06-24                  NaN
# 199997  2023-04-27T16:36:43.263341    2016-06-24                  NaN
# 199998  2023-05-05T01:10:08.345095    2020-08-18                  NaN
# 199999  2023-05-03T16:55:13.762420    2017-09-15                  NaN
#
# [200000 rows x 33 columns]

# %%
# 중복삭제 (id 컬럼 기준)
df = df.drop_duplicates(subset=['id']).reset_index(drop=True)
df
# Out:
#                                       id
# 0       https://openalex.org/W2046389536  \
# 1       https://openalex.org/W2757065440
# 2       https://openalex.org/W1969235198
# 3       https://openalex.org/W4229064923
# 4       https://openalex.org/W1570677810
# ...                                  ...
# 199947  https://openalex.org/W4283748928
# 199948  https://openalex.org/W2057696289
# 199949  https://openalex.org/W1980630824
# 199950  https://openalex.org/W3048378484
# 199951  https://openalex.org/W2751734142
#
#                                                     doi
# 0       https://doi.org/10.1109/isgteurope.2014.7028916  \
# 1                     https://doi.org/10.1115/1.4038048
# 2             https://doi.org/10.1109/ecce.2012.6342824
# 3             https://doi.org/10.1016/j.est.2022.104629
# 4                       https://doi.org/10.2172/1048985
# ...                                                 ...
# 199947               https://doi.org/10.3390/en15134800
# 199948       https://doi.org/10.1109/mspec.2013.6511107
# 199949  https://doi.org/10.1109/isgteurope.2012.6465753
# 199950            https://doi.org/10.3390/polym12081795
# 199951    https://doi.org/10.1016/j.ecolind.2017.08.054
#
#                                                     title
# 0              A review of demand response business cases  \
# 1       Sizing of a Photovoltaic-Wind-Oil Shale Hybrid...
# 2       Black start control of a solid state transform...
# 3       Application of load frequency control method t...
# 4       Zero Emission Bay Area (ZEBA) Fuel Cell Bus De...
# ...                                                   ...
# 199947  Simulation of Two-Phase Flow and Syngas Genera...
# 199948                  Germany jump-starts the supergrid
# 199949  Communication interface requirements during cr...
# 199950  Insights into the Potential of Hardwood Kraft ...
# 199951             Exergy analysis of Chinese agriculture
#
#                                              display_name  relevance_score
# 0              A review of demand response business cases       114.100780  \
# 1       Sizing of a Photovoltaic-Wind-Oil Shale Hybrid...       114.092880
# 2       Black start control of a solid state transform...       114.091770
# 3       Application of load frequency control method t...       114.088646
# 4       Zero Emission Bay Area (ZEBA) Fuel Cell Bus De...       114.087600
# ...                                                   ...              ...
# 199947  Simulation of Two-Phase Flow and Syngas Genera...        50.820840
# 199948                  Germany jump-starts the supergrid        50.819770
# 199949  Communication interface requirements during cr...        50.818558
# 199950  Insights into the Potential of Hardwood Kraft ...        50.818478
# 199951             Exergy analysis of Chinese agriculture        50.817660
#
#         publication_year publication_date
# 0                   2014       2014-10-01  \
# 1                   2018       2018-02-01
# 2                   2012       2012-11-12
# 3                   2022       2022-08-01
# 4                   2012       2012-07-01
# ...                  ...              ...
# 199947              2022       2022-06-30
# 199948              2013       2013-05-02
# 199949              2012       2012-10-01
# 199950              2020       2020-08-11
# 199951              2017       2017-08-31
#
#                                                       ids
# 0       {'openalex': 'https://openalex.org/W2046389536...  \
# 1       {'openalex': 'https://openalex.org/W2757065440...
# 2       {'openalex': 'https://openalex.org/W1969235198...
# 3       {'openalex': 'https://openalex.org/W4229064923...
# 4       {'openalex': 'https://openalex.org/W1570677810...
# ...                                                   ...
# 199947  {'openalex': 'https://openalex.org/W4283748928...
# 199948  {'openalex': 'https://openalex.org/W2057696289...
# 199949  {'openalex': 'https://openalex.org/W1980630824...
# 199950  {'openalex': 'https://openalex.org/W3048378484...
# 199951  {'openalex': 'https://openalex.org/W2751734142...
#
#                                          primary_location
# 0       {'is_oa': False, 'landing_page_url': 'https://...  \
# 1       {'is_oa': False, 'landing_page_url': 'https://...
# 2       {'is_oa': False, 'landing_page_url': 'https://...
# 3       {'is_oa': False, 'landing_page_url': 'https://...
# 4       {'is_oa': False, 'landing_page_url': 'https://...
# ...                                                   ...
# 199947  {'is_oa': True, 'landing_page_url': 'https://d...
# 199948  {'is_oa': False, 'landing_page_url': 'https://...
# 199949  {'is_oa': False, 'landing_page_url': 'https://...
# 199950  {'is_oa': True, 'landing_page_url': 'https://d...
# 199951  {'is_oa': False, 'landing_page_url': 'https://...
#
#                        type  ...
# 0       proceedings-article  ...  \
# 1           journal-article  ...
# 2       proceedings-article  ...
# 3           journal-article  ...
# 4                    report  ...
# ...                     ...  ...
# 199947      journal-article  ...
# 199948      journal-article  ...
# 199949  proceedings-article  ...
# 199950      journal-article  ...
# 199951      journal-article  ...
#
#                                                    grants
# 0                                                      []  \
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 199947  [{'funder': 'https://openalex.org/F4320311970'...
# 199948                                                 []
# 199949                                                 []
# 199950                                                 []
# 199951                                                 []
#
#                                          referenced_works
# 0       [https://openalex.org/W1787290749, https://ope...  \
# 1       [https://openalex.org/W1779223984, https://ope...
# 2       [https://openalex.org/W2136700375, https://ope...
# 3       [https://openalex.org/W1975774546, https://ope...
# 4       [https://openalex.org/W260040727, https://open...
# ...                                                   ...
# 199947  [https://openalex.org/W1965166118, https://ope...
# 199948                                                 []
# 199949  [https://openalex.org/W160743974, https://open...
# 199950  [https://openalex.org/W1160305686, https://ope...
# 199951  [https://openalex.org/W293584014, https://open...
#
#                                             related_works
# 0       [https://openalex.org/W1497055392, https://ope...  \
# 1       [https://openalex.org/W1965384568, https://ope...
# 2       [https://openalex.org/W1992568949, https://ope...
# 3       [https://openalex.org/W2059288099, https://ope...
# 4       [https://openalex.org/W289857799, https://open...
# ...                                                   ...
# 199947  [https://openalex.org/W58903434, https://opena...
# 199948  [https://openalex.org/W2080674165, https://ope...
# 199949  [https://openalex.org/W1480216841, https://ope...
# 199950  [https://openalex.org/W2045342989, https://ope...
# 199951  [https://openalex.org/W1572889832, https://ope...
#
#                                                ngrams_url
# 0       https://api.openalex.org/works/W2046389536/ngrams  \
# 1       https://api.openalex.org/works/W2757065440/ngrams
# 2       https://api.openalex.org/works/W1969235198/ngrams
# 3       https://api.openalex.org/works/W4229064923/ngrams
# 4       https://api.openalex.org/works/W1570677810/ngrams
# ...                                                   ...
# 199947  https://api.openalex.org/works/W4283748928/ngrams
# 199948  https://api.openalex.org/works/W2057696289/ngrams
# 199949  https://api.openalex.org/works/W1980630824/ngrams
# 199950  https://api.openalex.org/works/W3048378484/ngrams
# 199951  https://api.openalex.org/works/W2751734142/ngrams
#
#                                   abstract_inverted_index
# 0       {'Demand': [0], 'Response': [1], '(DR)': [2], ...  \
# 1       {'The': [0, 115, 175], 'integration': [1, 32, ...
# 2       {'This': [0], 'paper': [1, 60], 'demonstrates'...
# 3       {'Active': [0], 'power': [1], 'and': [2, 35, 5...
# 4       {'This': [0, 42], 'report': [1, 87, 109], 'pre...
# ...                                                   ...
# 199947  {'The': [0, 114], 'efficient': [1], 'use': [2]...
# 199948  {'New': [0], 'developments': [1], 'in': [2, 11...
# 199949  {'The': [0], 'power': [1, 35], 'system': [2, 3...
# 199950  {'Lignin': [0], 'is': [1, 143, 169], 'an': [2]...
# 199951  {'•': [0, 13, 24, 34, 46], 'An': [1], 'in-dept...
#
#                                          cited_by_api_url
# 0       https://api.openalex.org/works?filter=cites:W2...  \
# 1       https://api.openalex.org/works?filter=cites:W2...
# 2       https://api.openalex.org/works?filter=cites:W1...
# 3       https://api.openalex.org/works?filter=cites:W4...
# 4       https://api.openalex.org/works?filter=cites:W1...
# ...                                                   ...
# 199947  https://api.openalex.org/works?filter=cites:W4...
# 199948  https://api.openalex.org/works?filter=cites:W2...
# 199949  https://api.openalex.org/works?filter=cites:W1...
# 199950  https://api.openalex.org/works?filter=cites:W3...
# 199951  https://api.openalex.org/works?filter=cites:W2...
#
#                                            counts_by_year
# 0       [{'year': 2022, 'cited_by_count': 1}, {'year':...  \
# 1       [{'year': 2023, 'cited_by_count': 1}, {'year':...
# 2       [{'year': 2023, 'cited_by_count': 1}, {'year':...
# 3       [{'year': 2023, 'cited_by_count': 6}, {'year':...
# 4       [{'year': 2017, 'cited_by_count': 2}, {'year':...
# ...                                                   ...
# 199947              [{'year': 2022, 'cited_by_count': 2}]
# 199948  [{'year': 2022, 'cited_by_count': 4}, {'year':...
# 199949  [{'year': 2019, 'cited_by_count': 1}, {'year':...
# 199950  [{'year': 2023, 'cited_by_count': 10}, {'year'...
# 199951  [{'year': 2023, 'cited_by_count': 3}, {'year':...
#
#                       updated_date  created_date is_authors_truncated
# 0       2023-04-28T01:22:00.357992    2016-06-24                  NaN
# 1       2023-04-30T20:01:45.378594    2017-10-06                  NaN
# 2       2023-04-27T17:49:20.876350    2016-06-24                  NaN
# 3       2023-04-28T15:21:50.399968    2022-05-08                  NaN
# 4       2023-05-04T07:36:42.511435    2016-06-24                  NaN
# ...                            ...           ...                  ...
# 199947  2023-05-03T06:13:00.570166    2022-07-02                  NaN
# 199948  2023-04-29T13:01:19.950514    2016-06-24                  NaN
# 199949  2023-04-27T16:36:43.263341    2016-06-24                  NaN
# 199950  2023-05-05T01:10:08.345095    2020-08-18                  NaN
# 199951  2023-05-03T16:55:13.762420    2017-09-15                  NaN
#
# [199952 rows x 33 columns]

# %%
# 초록 텍스트 복원(리스트형태에서 텍스트로)
def index_to_text(abstract_inverted_index):
    abstract_index = {}
    for k, vlist in abstract_inverted_index.items():
        for v in vlist:
            abstract_index[v] = k
    abstract = ' '.join(abstract_index[k] for k in sorted(abstract_index.keys()))
    return abstract

# %%
# 초록 복원 테스트
index_to_text(df['abstract_inverted_index'][0])
# Out:
# 'Demand Response (DR) is widely held to be an essential part of future power systems. DR is expected to support integration of distributed generation from Renewable Energy Sources (RES) as well as to facilitate demand-side participation in power and ancillary service markets. This paper critically analyzes several business models from both a Distribution System Operator (DSO) and retailer perspective, and identifies opportunity costs associated with the trade-off between demand flexibility and energy acquisition cost. Numerical results from previous studies are gathered and compared to the control and communication complexity. Finally, regulatory issues are reviewed.'

# %%
# 초록 복원 결과를 'abstract' 컬럼에 추가
df['abstract'] = df[~pd.isna(df['abstract_inverted_index'])]['abstract_inverted_index'].progress_map(lambda x:index_to_text(x))
# Out:
# 100%|██████████| 199952/199952 [00:09<00:00, 22119.44it/s]

# %%
df['abstract']
# Out:
# 0         Demand Response (DR) is widely held to be an e...
# 1         The integration between renewable energy syste...
# 2         This paper demonstrates the black start capabi...
# 3         Active power and frequency control reflecting ...
# 4         This report presents results of a demonstratio...
#                                 ...
# 199947    The efficient use of renewable energy is recei...
# 199948    New developments in high-voltage DC electronic...
# 199949    The power system is changing rapidly also due ...
# 199950    Lignin is an abundant, renewable, and relative...
# 199951    • An in-depth exergy analysis of Chinese agric...
# Name: abstract, Length: 199952, dtype: object
